# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('training_log_last.csv')
df
# Out:
#     Unnamed: 0  Epoch  Generator Loss  Discriminator Loss  Cycle Loss  \
# 0            0      1        4.100230            3.625710    0.380010
# 1            1      2        3.685439            3.358548    0.349261
# 2            2      3        3.414710            3.210927    0.327499
# 3            3      4        3.185867            3.040159    0.310937
# 4            4      5        2.932700            2.929445    0.298145
# 5            5      6        2.801921            2.804794    0.285350
# 6            6      7        2.657805            2.744513    0.275006
# 7            7      8        2.568159            2.632847    0.269758
# 8            8      9        2.433897            2.609753    0.265612
# 9            9     10        2.391491            2.514173    0.258368
# 10          10     11        2.320789            2.485543    0.249626
# 11          11     12        2.292020            2.453204    0.247875
# ...

# %%
plt.plot(df['Generator Loss'], label='Generator Loss')
plt.plot(df['Discriminator Loss'], label='Discriminator Loss')
plt.xlabel("Epochs")
plt.legend()
plt.show()

# %%
plt.plot(df['Cycle Loss'], label='Cycle Loss')
plt.xlabel("Epochs")
plt.legend()
plt.show()
